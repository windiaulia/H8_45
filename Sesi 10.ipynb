# %% [markdown]
# # Inferential Statistics with Python

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import Math, Latex
from IPython.core.display import Image
from scipy.stats import uniform, norm, gamma, expon, poisson, binom, bernoulli

# seaborn configuration
sns.set(color_codes=True)
sns.set(rc={"figure.figsize": (5,5)})

# %%
conda install statsmodels
# Out:
# Note: you may need to restart the kernel to use updated packages.
# EnvironmentLocationNotFound: Not a conda environment: C:\Users\Windi

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\windi aulia\anaconda3\envs\hacktiv8-env\lib\site-packages (0.12.1)
# Requirement already satisfied: patsy>=0.5 in c:\users\windi aulia\anaconda3\envs\hacktiv8-env\lib\site-packages (from statsmodels) (0.5.1)
# Requirement already satisfied: scipy>=1.1 in c:\users\windi aulia\anaconda3\envs\hacktiv8-env\lib\site-packages (from statsmodels) (1.5.4)
# Requirement already satisfied: pandas>=0.21 in c:\users\windi aulia\anaconda3\envs\hacktiv8-env\lib\site-packages (from statsmodels) (1.1.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\windi aulia\anaconda3\envs\hacktiv8-env\lib\site-packages (from statsmodels) (1.19.2)
# Requirement already satisfied: six in c:\users\windi aulia\anaconda3\envs\hacktiv8-env\lib\site-packages (from patsy>=0.5->statsmodels) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\windi aulia\anaconda3\envs\hacktiv8-env\lib\site-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\windi aulia\anaconda3\envs\hacktiv8-env\lib\site-packages (from pandas>=0.21->statsmodels) (2020.4)

# %%
import statsmodels.api as sm

# %%
def plot_distribution(data, title):
    ax = sns.displot(
        data,
        bins=100,
        kde=True,
        color="skyblue",
        linewidth=15,
        alpha=1
    )
    ax.set(xlabel=title, ylabel="Frequency")
    plt.title(title)
    plt.show()

# %% [markdown]
# ## Uniform Distribution

# %%
n = 100
loc = 10
scale = 20
rv_uniform = uniform.rvs(loc=loc, scale=scale, size=n)

# plot distribution
ax = sns.displot(rv_uniform, color="skyblue", linewidth=1.5, alpha=1, kde=True)
ax.set(xlabel="Uniform Distribution", ylabel="Frequency")
plt.show()

# %%
rv_uniform
# Out:
# array([27.96690551, 23.62645446, 17.16589774, 10.57374273, 20.02198086,
#        23.3811788 , 18.41170586, 29.38529073, 20.35482159, 26.32981415,
#        10.0415706 , 15.41284301, 10.85195171, 27.08383984, 26.69707839,
#        12.49215113, 22.63056939, 27.18484685, 28.24391944, 27.71779034,
#        17.82516501, 10.76004288, 25.95817007, 13.06982256, 10.13942362,
#        29.05361661, 28.71873919, 28.52801883, 24.50821113, 15.26299899,
#        28.63908339, 22.45913636, 21.35006093, 20.58225559, 20.59995269,
#        11.89625775, 15.11435792, 21.32594737, 24.52390722, 16.63038774,
#        28.98363818, 27.6743321 , 16.23383624, 13.84505489, 14.51051831,
#        25.94741384, 17.53743216, 16.87403832, 27.92761788, 14.21038158,
#        11.14853616, 10.35783896, 20.45925551, 18.13982721, 29.64606045,
#        24.44429935, 17.81024224, 17.2625016 , 28.71998682, 23.15268183,
#        21.01987186, 20.7402492 , 24.61526904, 10.33657115, 18.79905369,
#        26.68887138, 27.00563084, 27.72484557, 24.55403501, 24.93614657,
#        26.90262975, 29.59104957, 12.19875597, 10.19991818, 15.2987448 ,
#        12.91573116, 24.68552036, 22.69422662, 15.74446151, 29.20809799,
#        16.52778973, 14.48143528, 20.65908994, 13.99773177, 27.71862717,
#        21.05474388, 28.54902662, 10.53072704, 10.56957833, 13.64710278,
#        18.09263816, 13.31298843, 10.14405533, 12.50634028, 13.5466195 ,
#        17.64677848, 13.08950415, 23.51278544, 29.76812693, 26.4002965 ])

# %%
n = 10000
loc = 10
scale = 20
rv_uniform = uniform.rvs(loc=loc, scale=scale, size=n)

# plot distribution
ax = sns.displot(rv_uniform, color="skyblue", linewidth=15, alpha=1, kde=True, bins=100)
ax.set(xlabel="Uniform Distribution", ylabel="Frequency")
plt.title("Uniform Distribution")
plt.show()

# %%
n = 10000
loc = 10
scale = 20
rv_uniform = uniform.rvs(loc=loc, scale=scale, size=n)

# plot distribution
ax = sns.displot(rv_uniform, kind="kde")
ax.set(xlabel="Uniform Distribution", ylabel="Frequency")
plt.title("Uniform Distribution")
plt.show()

# %% [markdown]
# ## Normal Distribution

# %%
n = 10000
loc = 0
scale = 1
rv_normal = norm.rvs(loc=loc, scale=scale, size=n)

# plot distribution
ax = sns.displot(rv_normal, bins=100, kde=True, color="skyblue", linewidth=15, alpha=1)
ax.set(xlabel="Normal Distribution", ylabel="Frequency")
plt.title("Normal Distribution")
plt.show()

# %%
plot_distribution(rv_normal, "Normal Distribution")

# %%
plot_distribution(
    norm.rvs(loc=0, scale=5, size=10000),
    "Normal Distribution"
)

# %% [markdown]
# ## Gamma Distribution

# %%
n = 10000
a = 5
loc = 5
scale = 10
rv_gamma = gamma.rvs(a=a, loc=loc, scale=scale, size=n)
plot_distribution(rv_gamma, f"Gamma Distribution (a={a}, loc={loc}, scale={scale})")

n = 10000
a = 5
rv_gamma = gamma.rvs(a=a, size=n)
plot_distribution(rv_gamma, f"Gamma Distribution(a={a})")

# %%
n = 10000
a = 1
loc = 5
scale = 10
rv_gamma = gamma.rvs(a=a, loc=loc, scale=scale, size=n)
plot_distribution(rv_gamma, f"Gamma Distribution (a={a}, loc={loc}, scale={scale})")

n = 10000
a = 1
rv_gamma = gamma.rvs(a=a, size=n)
plot_distribution(rv_gamma, f"Gamma Distribution(a={a})")

# %% [markdown]
# ## Exponential Distribution

# %%
n = 10000
loc = 0
scale = 1
rv_exponential = expon.rvs(loc=loc, scale=scale, size=n)
plot_distribution(rv_exponential, "Exponential Distribution")

# %% [markdown]
# ## Binomial Distribution

# %%
size = 1000
n = 10
p = .8
rv_binomial = binom.rvs(n=n, p=p, size=size)
plot_distribution(rv_binomial, f"Binomial Distribution with Success Rate{p}")

size = 1000
n = 10
p = .5
rv_binomial = binom.rvs(n=n, p=p, size=size)
plot_distribution(rv_binomial, f"Binomial Distribution with Success Rate{p}")

# %%
size = 1000
n = 10
p = .8
rv_binomial = np.random.binomial(n, p, size)
plot_distribution(rv_binomial, f"Binomial Distribution with Success Rate{p}")

size = 1000
n = 10
p = .5
rv_binomial = np.random.binomial(n, p, size)
plot_distribution(rv_binomial, f"Binomial Distribution with Success Rate{p}")

# %% [markdown]
# ## Bernoulli Distribution

# %%
size = 10000
p = .6
rv_bernoulli = bernoulli.rvs(p=p, size=size)
plot_distribution(rv_bernoulli, "Bernoulli Distribution")

size = 10000
p = .5
rv_bernoulli = bernoulli.rvs(p=p, size=size)
plot_distribution(rv_bernoulli, "Bernoulli Distribution")

# %% [markdown]
# ## Poisson Distribution

# %%
size = 10000
mu = 3
rv_poisson = poisson.rvs(mu=mu, size=size)
plot_distribution(rv_poisson, "Poisson Distribution")

# %%
np.random.seed(111)
np.random.normal(loc=0, scale=1, size=10)
# Out:
# array([-1.13383833,  0.38431919,  1.49655378, -0.3553823 , -0.78753354,
#        -0.45943891, -0.05916877, -0.3541735 , -0.73552305, -1.18393989])

# %%
rng = np.random.default_rng(111)     # using default random number generator
rng.normal(loc=0, scale=1, size=10)
# Out:
# array([-0.30743784, -0.8386569 ,  0.12563787, -0.66067729,  0.15831516,
#         2.43876182,  0.43963253,  0.77035284, -0.79443326, -0.90645504])

# %% [markdown]
# ## Confidence Interval

# %%
heart = pd.read_csv("data/heart.csv")
print("Dataset Shape:", heart.shape)
display(heart.head())
# Out:
# Dataset Shape: (1025, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart["sex"] = heart.sex.replace({1: "Male", 0:"Female"})
heart.head()
# Out:
#    age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    Male   0       125   212    0        1      168      0      1.0
# 1   53    Male   0       140   203    1        0      155      1      3.1
# 2   70    Male   0       145   174    0        1      125      1      2.6
# 3   61    Male   0       148   203    0        1      161      0      0.0
# 4   62  Female   0       138   294    1        1      106      0      1.9
#
#    slope  ca  thal  target
# 0      2   2     3       0
# 1      0   0     3       0
# 2      0   0     3       0
# 3      2   1     3       0
# 4      1   3     2       0

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   object
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(12), object(1)
# memory usage: 112.2+ KB

# %%
heart.sex.value_counts()
# Out:
# Male      713
# Female    312
# Name: sex, dtype: int64

# %%
cross_tab = pd.crosstab(heart.target, heart.sex)

# %%
cross_tab["Total"] = cross_tab["Female"] + cross_tab["Male"] 
cross_tab
# Out:
# sex     Female  Male  Total
# target
# 0           86   413    499
# 1          226   300    526

# %%
pop_female = 312
pop_male = 713

prop_female = 226 / pop_female
print("Proportion of female having disease:", prop_female)
# Out:
# Proportion of female having disease: 0.7243589743589743

# %%
stderr_female = np.sqrt(prop_female * (1-prop_female) / pop_female)
print("Standard error for female proportion:", stderr_female)
# Out:
# Standard error for female proportion: 0.02529714756803247

# %%
def compute_CI(estimate, stderr, z_score=1.96):
    return (
        estimate - z_score*stderr, # lower limit of the CI
        estimate + z_score*stderr  # Upper limit of the CI
    )

# %%
lower_ci, upper_ci = compute_CI(prop_female, stderr_female)
print(f"CI for female proportion having disease: [{lower_ci:.3f}, {upper_ci: .3f}]")
# Out:
# CI for female proportion having disease: [0.675,  0.774]

# %% [markdown]
# ### CI for Mean

# %%
heart.head()
# Out:
#    age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    Male   0       125   212    0        1      168      0      1.0
# 1   53    Male   0       140   203    1        0      155      1      3.1
# 2   70    Male   0       145   174    0        1      125      1      2.6
# 3   61    Male   0       148   203    0        1      161      0      0.0
# 4   62  Female   0       138   294    1        1      106      0      1.9
#
#    slope  ca  thal  target
# 0      2   2     3       0
# 1      0   0     3       0
# 2      0   0     3       0
# 3      2   1     3       0
# 4      1   3     2       0

# %%
heart.groupby("sex").aggregate({"chol": [np.mean, np.std, np.size]})
# Out:
#               chol
#               mean        std size
# sex
# Female  261.455128  64.466781  312
# Male    239.237027  43.155535  713

# %%
mean_female_chol = 261.455
std_female_chol = 64.467
n_female = 312
z = 1.96

stderr_mean_female = std_female_chol / np.sqrt(n_female)
print("Standard error mean of female chol:", stderr_mean_female)
# Out:
# Standard error mean of female chol: 3.6497251780099824

# %%
lower_ci, upper_ci = compute_CI(mean_female_chol, stderr_mean_female)
print(f"CI for female proportion having disease: [{lower_ci:.3f}, {upper_ci: .3f}]")
# Out:
# CI for female proportion having disease: [254.302,  268.608]

# %% [markdown]
# ## Hypothesis Testing

# %%
n = 1018
pnull = .52
phat = .56

# %%
sm.stats.proportions_ztest(phat * n, n, pnull, alternative="larger")
# Out:
# (2.571067795759113, 0.005069273865860533)

# %%
nhanes = pd.read_csv("data/nhanes_2015_2016.csv")
nhanes
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0     83732     1.0     NaN     1.0       1         1        62         3
# 1     83733     1.0     NaN     6.0       1         1        53         3
# 2     83734     1.0     NaN     NaN       1         1        78         3
# 3     83735     2.0     1.0     1.0       2         2        56         3
# 4     83736     2.0     1.0     1.0       2         2        42         4
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5730  93695     2.0     2.0     NaN       1         2        76         3
# 5731  93696     2.0     2.0     NaN       2         1        26         3
# 5732  93697     1.0     NaN     1.0       1         2        80         3
# 5733  93700     NaN     NaN     NaN       1         1        35         3
# 5734  93702     1.0     NaN     2.0       2         2        24         3
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0          1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1          2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2          1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3          1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4          1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
# ...        ...       ...  ...     ...     ...    ...    ...     ...     ...
# 5730       1.0       3.0  ...   112.0    46.0   59.1  165.8    21.5    38.2
# 5731       1.0       5.0  ...   116.0    76.0  112.1  182.2    33.8    43.4
# 5732       1.0       4.0  ...   146.0    58.0   71.7  152.2    31.0    31.3
# 5733       2.0       1.0  ...   106.0    66.0   78.2  173.3    26.0    40.3
# 5734       1.0       5.0  ...   114.0    68.0   58.3  165.0    21.4    38.2
#
#       BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0        43.6     35.9     101.1     2.0
# 1        40.0     33.2     107.9     NaN
# 2        37.0     31.0     116.5     2.0
# 3        37.7     38.3     110.1     2.0
# 4        36.0     27.2      80.4     2.0
# ...       ...      ...       ...     ...
# 5730     37.0     29.5      95.0     2.0
# 5731     41.8     42.3     110.2     2.0
# 5732     37.5     28.8       NaN     2.0
# 5733     37.5     30.6      98.9     2.0
# 5734     33.5     26.2      72.5     2.0
#
# [5735 rows x 28 columns]

# %%
nhanes_female = nhanes[nhanes["RIAGENDR"] == 2]
nhanes_male = nhanes[nhanes["RIAGENDR"] == 1]

# num of observation
num_female = len(nhanes_female)
num_male = len(nhanes_male)

# mean
mu_female = nhanes_female.BMXBMI.mean()
mu_male = nhanes_male.BMXBMI.mean()

# std
std_female = nhanes_female.BMXBMI.std()
std_male = nhanes_male.BMXBMI.std()

# %%
sm.stats.ztest(nhanes_female.BMXBMI.dropna(), nhanes_male.BMXBMI.dropna(), alternative="two-sided")
# Out:
# (6.1755933531383205, 6.591544431126401e-10)
